# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import time, datetime, timedelta
import random

# Parameters
hours_open = 11  # Assuming 8 hours of operation per day
average_customers_per_day = 100  # Average customers per day

def generatePoissonProcessArrivals(hours_open, average_customers_per_day):
    lambda_val = average_customers_per_day / hours_open
    total_customers = np.random.poisson(average_customers_per_day)
    arrival_times = np.cumsum(np.random.exponential(1 / lambda_val, total_customers) * 60)
    return arrival_times


arrival_times = generatePoissonProcessArrivals(hours_open, average_customers_per_day)

def generateIncomingDemandTimestamps(arrival_times):
    start_time = datetime.strptime('08:00', '%H:%M')
    arrival_datetimes = [start_time + timedelta(minutes=int(t)) for t in arrival_times]
    arrival_minutes = [(dt - start_time).seconds // 60 for dt in arrival_datetimes]
    # Print arrival timestamps
    print(len(arrival_minutes),"customers arrived!")
    arrival_timestamps = [dt.strftime('%H:%M:%S') for dt in arrival_datetimes]
    
    return arrival_timestamps



arrival_timestamps = generateIncomingDemandTimestamps(arrival_times)
# Out:
# 92 customers arrived!

# %%
class Pharmacy:
    def __init__(self, pharmacy_name, initial_balance, initial_inventory, old_inventory, unit_cost = 10, 
                 unit_revenue = 20, holding_cost = 2, outdating_cost = 5):
        self.balance = initial_balance
        self.name = pharmacy_name
        self.inventory = {'new': initial_inventory, 'old': old_inventory}
        self.revenue_per_unit = unit_revenue
        self.cost_per_unit = unit_cost
        self.holding_cost = holding_cost
        self.outdating_cost = outdating_cost
    
    def replenish(self, amount):
        self.inventory['new'] += amount
        self.balance -= amount * self.cost_per_unit  # Assume each replenished item costs 10 unit of currency
    
    def process_day_end(self):
        # Apply holding cost for all items
        total_inventory = self.inventory['new'] + self.inventory['old']
        self.balance -= self.holding_cost * total_inventory
        
        # Apply outdating cost for old items that perish
        self.balance -= self.outdating_cost * self.inventory['old']

        # 'old' items perish at the end of the day
        self.inventory['old'] = 0
        # 'new' items become 'old' at the end of the day
        self.inventory['old'] = self.inventory['new']
        self.inventory['new'] = 0
    
    # FIFO 
    def fulfill_demand(self):
        if self.inventory['old'] > 0:
            self.inventory['old'] -= 1
            self.balance += self.revenue_per_unit
            return True
        elif self.inventory['new'] > 0:
            self.inventory['new'] -= 1
            self.balance += self.revenue_per_unit
            return True
        else:
            # Implicit lost sales cost (not explicit) = - (revenue - cost)
            lost_sales_cost = -(self.revenue_per_unit - self.cost_per_unit)
            self.balance += lost_sales_cost
            return False
            print("No inventory to fulfill demand")
           
    def get_inventory_level(self):
        return self.inventory['new'] + self.inventory['old']
    
    def get_shelf_life_value(self):
        return 2 * self.inventory['new'] + self.inventory['old']
    
    def get_name(self):
        return "Pharmacy " + self.name
    
    def __str__(self):
        return f"Balance: {self.balance}, Inventory: {self.inventory}"
    
    def __repr__(self):
        return self.get_name()

# %%
def convert_to_time(timestamp_str):
    return datetime.strptime(timestamp_str, "%H:%M:%S").time()

def isValidArrival(arrival_time):
    if(convert_to_time(arrival_time) >= opening_time and convert_to_time(arrival_time) <= closing_time):
        return True
    else:
        return False
    
def g(x):
    if x < 0:
        return -1
    elif x == 0:
        return 0
    else:
        return 1
    
def get_winner(pharmacy1, pharmacy2):
    if(pharmacy1.balance > pharmacy2.balance):
        return pharmacy1.get_name()
    elif(pharmacy1.balance < pharmacy2.balance):
        return pharmacy2.get_name()
    else:
        return "tie"
    
def fulfillIncomingDemand(chosen_pharmacy, other_pharmacy):
    if chosen_pharmacy.fulfill_demand():
        return None
    else:
        other_pharmacy.fulfill_demand()
    
def calculate_fulfillment_metric(I1, I2, V1, V2, w1 = 1, w2 = 1):
    if max(I1, I2) == 0:
        normalized_inventory_difference = 0
    else:
        normalized_inventory_difference = (g(I1 - I2) * abs(I1 - I2)) / max(I1, I2)
    return w1 * normalized_inventory_difference + w2 * (V1 - V2)

def simulate_day(arrival_timestamps, initial_balance, replenish_amount):
    invalid_arrivals = []

    pharmacy1 = Pharmacy("1", initial_balance, 20, 10)
    pharmacy2 = Pharmacy("2", initial_balance2, 10, 10)
    
    pharmacy1.replenish(replenish_amount)
    pharmacy2.replenish(replenish_amount2)
    
    print("Replenishment is done, Inventory levels at the beginning of day:")
    print(f"Pharmacy 1: {pharmacy1}")
    print(f"Pharmacy 2: {pharmacy2}")
    
    for timestamp in arrival_timestamps:
        if(isValidArrival(timestamp)):
            I1 = pharmacy1.get_inventory_level()
            I2 = pharmacy2.get_inventory_level()
            V1 = pharmacy1.get_shelf_life_value()
            V2 = pharmacy2.get_shelf_life_value()

            fulfillment_metric = calculate_fulfillment_metric(I1, I2, V1, V2)
            print(fulfillment_metric)

            if fulfillment_metric > 0:
                chosen_pharmacy = pharmacy1
                other_pharmacy = pharmacy1 if chosen_pharmacy == pharmacy2 else pharmacy2
                fulfillIncomingDemand(chosen_pharmacy, other_pharmacy)
            elif fulfillment_metric < 0:
                chosen_pharmacy = pharmacy2
                other_pharmacy = pharmacy1 if chosen_pharmacy == pharmacy2 else pharmacy2
                fulfillIncomingDemand(chosen_pharmacy, other_pharmacy)
            else:
                chosen_pharmacy = random.choice([pharmacy1, pharmacy2])
                other_pharmacy = pharmacy1 if chosen_pharmacy == pharmacy2 else pharmacy2
                fulfillIncomingDemand(chosen_pharmacy, other_pharmacy)
                
            print(f"At timestamp {timestamp}, chosen pharmacy: {chosen_pharmacy.get_name()}")
            print(f"Pharmacy 1: {pharmacy1}")
            print(f"Pharmacy 2: {pharmacy2}")
        else:
            invalid_arrivals.append(timestamp)

        
    # Process end of day changes
    pharmacy1.process_day_end()
    pharmacy2.process_day_end()
    
    print("End of day:")
    print(f"Pharmacy 1: {pharmacy1}")
    print(f"Pharmacy 2: {pharmacy2}")
    print(f"# of unresponsive customer: {len(invalid_arrivals)}")
    print("- - - - - - - - - - - - -")
    print(f"Winner: {get_winner(pharmacy1, pharmacy2)}")

# %%
initial_balance = 100
initial_balance2 = 100
replenish_amount = 5
replenish_amount2 = 5
opening_time = time(8, 0, 0)
closing_time = time(18, 0, 0)


simulate_day(arrival_timestamps, initial_balance, replenish_amount)
# Out:
# Replenishment is done, Inventory levels at the beginning of day:
# Pharmacy 1: Balance: 50, Inventory: {'new': 25, 'old': 10}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 20.285714285714285
# At timestamp 08:15:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 70, Inventory: {'new': 25, 'old': 9}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 19.264705882352942
# At timestamp 08:31:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 90, Inventory: {'new': 25, 'old': 8}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 18.242424242424242
# At timestamp 08:44:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 110, Inventory: {'new': 25, 'old': 7}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 17.21875
# At timestamp 08:48:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 130, Inventory: {'new': 25, 'old': 6}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 16.193548387096776
# At timestamp 08:55:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 150, Inventory: {'new': 25, 'old': 5}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 15.166666666666666
# At timestamp 09:08:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 170, Inventory: {'new': 25, 'old': 4}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 14.137931034482758
# At timestamp 09:22:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 190, Inventory: {'new': 25, 'old': 3}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 13.107142857142858
# At timestamp 09:24:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 210, Inventory: {'new': 25, 'old': 2}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 12.074074074074074
# At timestamp 09:29:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 230, Inventory: {'new': 25, 'old': 1}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 11.038461538461538
# At timestamp 09:31:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 250, Inventory: {'new': 25, 'old': 0}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 10.0
# At timestamp 09:38:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 270, Inventory: {'new': 24, 'old': 0}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 7.96
# At timestamp 09:39:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 290, Inventory: {'new': 23, 'old': 0}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 5.92
# At timestamp 09:44:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 310, Inventory: {'new': 22, 'old': 0}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 3.88
# At timestamp 09:51:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 330, Inventory: {'new': 21, 'old': 0}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# 1.84
# At timestamp 10:02:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 350, Inventory: {'new': 20, 'old': 0}
# Pharmacy 2: Balance: 50, Inventory: {'new': 15, 'old': 10}
# -0.2
# At timestamp 10:04:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 350, Inventory: {'new': 20, 'old': 0}
# Pharmacy 2: Balance: 70, Inventory: {'new': 15, 'old': 9}
# 0.8333333333333334
# At timestamp 10:07:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 370, Inventory: {'new': 19, 'old': 0}
# Pharmacy 2: Balance: 70, Inventory: {'new': 15, 'old': 9}
# -1.2083333333333333
# At timestamp 10:08:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 370, Inventory: {'new': 19, 'old': 0}
# Pharmacy 2: Balance: 90, Inventory: {'new': 15, 'old': 8}
# -0.17391304347826086
# At timestamp 10:10:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 370, Inventory: {'new': 19, 'old': 0}
# Pharmacy 2: Balance: 110, Inventory: {'new': 15, 'old': 7}
# 0.8636363636363636
# At timestamp 10:15:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 390, Inventory: {'new': 18, 'old': 0}
# Pharmacy 2: Balance: 110, Inventory: {'new': 15, 'old': 7}
# -1.1818181818181819
# At timestamp 10:16:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 390, Inventory: {'new': 18, 'old': 0}
# Pharmacy 2: Balance: 130, Inventory: {'new': 15, 'old': 6}
# -0.14285714285714285
# At timestamp 10:19:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 390, Inventory: {'new': 18, 'old': 0}
# Pharmacy 2: Balance: 150, Inventory: {'new': 15, 'old': 5}
# 0.9
# At timestamp 10:23:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 410, Inventory: {'new': 17, 'old': 0}
# Pharmacy 2: Balance: 150, Inventory: {'new': 15, 'old': 5}
# -1.15
# At timestamp 10:23:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 410, Inventory: {'new': 17, 'old': 0}
# Pharmacy 2: Balance: 170, Inventory: {'new': 15, 'old': 4}
# -0.10526315789473684
# At timestamp 10:28:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 410, Inventory: {'new': 17, 'old': 0}
# Pharmacy 2: Balance: 190, Inventory: {'new': 15, 'old': 3}
# 0.9444444444444444
# At timestamp 10:31:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 430, Inventory: {'new': 16, 'old': 0}
# Pharmacy 2: Balance: 190, Inventory: {'new': 15, 'old': 3}
# -1.1111111111111112
# At timestamp 10:32:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 430, Inventory: {'new': 16, 'old': 0}
# Pharmacy 2: Balance: 210, Inventory: {'new': 15, 'old': 2}
# -0.058823529411764705
# At timestamp 10:38:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 430, Inventory: {'new': 16, 'old': 0}
# Pharmacy 2: Balance: 230, Inventory: {'new': 15, 'old': 1}
# 1.0
# At timestamp 11:02:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 450, Inventory: {'new': 15, 'old': 0}
# Pharmacy 2: Balance: 230, Inventory: {'new': 15, 'old': 1}
# -1.0625
# At timestamp 11:25:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 450, Inventory: {'new': 15, 'old': 0}
# Pharmacy 2: Balance: 250, Inventory: {'new': 15, 'old': 0}
# 0.0
# At timestamp 11:31:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 470, Inventory: {'new': 14, 'old': 0}
# Pharmacy 2: Balance: 250, Inventory: {'new': 15, 'old': 0}
# -2.066666666666667
# At timestamp 11:31:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 470, Inventory: {'new': 14, 'old': 0}
# Pharmacy 2: Balance: 270, Inventory: {'new': 14, 'old': 0}
# 0.0
# At timestamp 11:57:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 490, Inventory: {'new': 13, 'old': 0}
# Pharmacy 2: Balance: 270, Inventory: {'new': 14, 'old': 0}
# -2.0714285714285716
# At timestamp 12:03:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 490, Inventory: {'new': 13, 'old': 0}
# Pharmacy 2: Balance: 290, Inventory: {'new': 13, 'old': 0}
# 0.0
# At timestamp 12:13:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 490, Inventory: {'new': 13, 'old': 0}
# Pharmacy 2: Balance: 310, Inventory: {'new': 12, 'old': 0}
# 2.076923076923077
# At timestamp 12:14:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 510, Inventory: {'new': 12, 'old': 0}
# Pharmacy 2: Balance: 310, Inventory: {'new': 12, 'old': 0}
# 0.0
# At timestamp 12:14:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 530, Inventory: {'new': 11, 'old': 0}
# Pharmacy 2: Balance: 310, Inventory: {'new': 12, 'old': 0}
# -2.0833333333333335
# At timestamp 12:36:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 530, Inventory: {'new': 11, 'old': 0}
# Pharmacy 2: Balance: 330, Inventory: {'new': 11, 'old': 0}
# 0.0
# At timestamp 12:40:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 550, Inventory: {'new': 10, 'old': 0}
# Pharmacy 2: Balance: 330, Inventory: {'new': 11, 'old': 0}
# -2.090909090909091
# At timestamp 12:41:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 550, Inventory: {'new': 10, 'old': 0}
# Pharmacy 2: Balance: 350, Inventory: {'new': 10, 'old': 0}
# 0.0
# At timestamp 12:57:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 570, Inventory: {'new': 9, 'old': 0}
# Pharmacy 2: Balance: 350, Inventory: {'new': 10, 'old': 0}
# -2.1
# At timestamp 13:02:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 570, Inventory: {'new': 9, 'old': 0}
# Pharmacy 2: Balance: 370, Inventory: {'new': 9, 'old': 0}
# 0.0
# At timestamp 13:12:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 570, Inventory: {'new': 9, 'old': 0}
# Pharmacy 2: Balance: 390, Inventory: {'new': 8, 'old': 0}
# 2.111111111111111
# At timestamp 13:13:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 590, Inventory: {'new': 8, 'old': 0}
# Pharmacy 2: Balance: 390, Inventory: {'new': 8, 'old': 0}
# 0.0
# At timestamp 13:13:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 610, Inventory: {'new': 7, 'old': 0}
# Pharmacy 2: Balance: 390, Inventory: {'new': 8, 'old': 0}
# -2.125
# At timestamp 13:18:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 610, Inventory: {'new': 7, 'old': 0}
# Pharmacy 2: Balance: 410, Inventory: {'new': 7, 'old': 0}
# 0.0
# At timestamp 13:20:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 630, Inventory: {'new': 6, 'old': 0}
# Pharmacy 2: Balance: 410, Inventory: {'new': 7, 'old': 0}
# -2.142857142857143
# At timestamp 13:21:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 630, Inventory: {'new': 6, 'old': 0}
# Pharmacy 2: Balance: 430, Inventory: {'new': 6, 'old': 0}
# 0.0
# At timestamp 13:36:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 650, Inventory: {'new': 5, 'old': 0}
# Pharmacy 2: Balance: 430, Inventory: {'new': 6, 'old': 0}
# -2.1666666666666665
# At timestamp 13:43:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 650, Inventory: {'new': 5, 'old': 0}
# Pharmacy 2: Balance: 450, Inventory: {'new': 5, 'old': 0}
# 0.0
# At timestamp 13:44:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 670, Inventory: {'new': 4, 'old': 0}
# Pharmacy 2: Balance: 450, Inventory: {'new': 5, 'old': 0}
# -2.2
# At timestamp 13:50:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 670, Inventory: {'new': 4, 'old': 0}
# Pharmacy 2: Balance: 470, Inventory: {'new': 4, 'old': 0}
# 0.0
# At timestamp 13:53:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 690, Inventory: {'new': 3, 'old': 0}
# Pharmacy 2: Balance: 470, Inventory: {'new': 4, 'old': 0}
# -2.25
# At timestamp 14:02:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 690, Inventory: {'new': 3, 'old': 0}
# Pharmacy 2: Balance: 490, Inventory: {'new': 3, 'old': 0}
# 0.0
# At timestamp 14:05:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 690, Inventory: {'new': 3, 'old': 0}
# Pharmacy 2: Balance: 510, Inventory: {'new': 2, 'old': 0}
# 2.3333333333333335
# At timestamp 14:14:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 710, Inventory: {'new': 2, 'old': 0}
# Pharmacy 2: Balance: 510, Inventory: {'new': 2, 'old': 0}
# 0.0
# At timestamp 14:17:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 730, Inventory: {'new': 1, 'old': 0}
# Pharmacy 2: Balance: 510, Inventory: {'new': 2, 'old': 0}
# -2.5
# At timestamp 14:18:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 730, Inventory: {'new': 1, 'old': 0}
# Pharmacy 2: Balance: 530, Inventory: {'new': 1, 'old': 0}
# 0.0
# At timestamp 14:30:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 750, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 530, Inventory: {'new': 1, 'old': 0}
# -3.0
# At timestamp 14:46:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 750, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 550, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 14:48:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 740, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 540, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 14:53:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 730, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 530, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 14:54:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 720, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 520, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 15:10:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 710, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 510, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 15:51:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 700, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 500, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 16:10:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 690, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 490, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 16:11:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 680, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 480, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 16:14:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 670, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 470, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 16:18:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 660, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 460, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 16:47:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 650, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 450, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 16:58:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 640, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 440, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 17:14:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 630, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 430, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 17:15:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 620, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 420, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 17:17:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 610, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 410, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 17:27:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 600, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 400, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 17:29:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 590, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 390, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 17:46:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 580, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 380, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 17:47:00, chosen pharmacy: Pharmacy 1
# Pharmacy 1: Balance: 570, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 370, Inventory: {'new': 0, 'old': 0}
# 0
# At timestamp 17:52:00, chosen pharmacy: Pharmacy 2
# Pharmacy 1: Balance: 560, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 360, Inventory: {'new': 0, 'old': 0}
# End of day:
# Pharmacy 1: Balance: 560, Inventory: {'new': 0, 'old': 0}
# Pharmacy 2: Balance: 360, Inventory: {'new': 0, 'old': 0}
# # of unresponsive customer: 13
# - - - - - - - - - - - - -
# Winner: Pharmacy 1
